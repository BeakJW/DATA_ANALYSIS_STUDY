# %% [markdown]
# # LAB 04 Data Preprocessing (2)
#
# ## 2. 행 기준 병합
#
# ### 라이브러리 참조

# %%
from pandas import DataFrame, concat

# %%
df1 = DataFrame({'이름':['영희','철수'],'국어':[97,91]})
df1
# Out:
#    이름  국어
# 0  영희  97
# 1  철수  91

# %%
df2 = DataFrame({'이름':['민철','수현'],'국어':[78,92]})
df2
# Out:
#    이름  국어
# 0  민철  78
# 1  수현  92

# %%
#### 1. 병합하기

# %%
concat([df1,df2])
# Out:
#    이름  국어
# 0  영희  97
# 1  철수  91
# 0  민철  78
# 1  수현  92

# %%
#### 2. 병합 결과에서 index를 재구성하기

# %%
재구성 = concat([df1,df2])
재구성.reset_index(inplace=True,drop=True)
재구성
# Out:
#    이름  국어
# 0  영희  97
# 1  철수  91
# 2  민철  78
# 3  수현  92

# %%
#### 2. 병합 결과에서 index를 재구성하기

# %%
concat([df1,df2],ignore_index=True)
# Out:
#    이름  국어
# 0  영희  97
# 1  철수  91
# 2  민철  78
# 3  수현  92

# %%
df3 = DataFrame({'이름':['영희','철수'],'국어':[97,91]})
df3
# Out:
#    이름  국어
# 0  영희  97
# 1  철수  91

# %%
df4 = DataFrame({'이름':['민철','수현'],'수학':[78,92]})
df4
# Out:
#    이름  수학
# 0  민철  78
# 1  수현  92

# %%
#### 데이터 병합 일치하지 않는 부분에 대해서는 𝑁𝑎𝑁으로 처리한다

# %%
concat([df3,df4],ignore_index=True)
# Out:
#    이름    국어    수학
# 0  영희  97.0   NaN
# 1  철수  91.0   NaN
# 2  민철   NaN  78.0
# 3  수현   NaN  92.0

# %%
df5 = DataFrame({'국어':[87,12,14]},index = ['민철','철수','민수'])
df5
# Out:
#     국어
# 민철  87
# 철수  12
# 민수  14

# %%
df6 = DataFrame({'국어':[37,42,54]},index = ['민철','수현','민수'])
df6
# Out:
#     국어
# 민철  37
# 수현  42
# 민수  54

# %%
#### 데이터 병합 인덱스도 함께 병합된다. 각 데이터 프레임간에 중복되는 인덱스가 존재할 경우 각 행은 개별적으로 존재한다. (인덱스 중복)

# %%
concat([df5,df6])
# Out:
#     국어
# 민철  87
# 철수  12
# 민수  14
# 민철  37
# 수현  42
# 민수  54

# %%
concat([df5,df6],ignore_index = True)
# Out:
#    국어
# 0  87
# 1  12
# 2  14
# 3  37
# 4  42
# 5  54
