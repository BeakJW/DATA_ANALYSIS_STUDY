# %% [markdown]
# # LAB 04 Data Preprocessing (1)
#
# ## #1. 열 기준 병합(1)
#
# ### 라이브러리 참조

# %%
from hossam import load_data
from pandas import DataFrame
from pandas import merge

# %% [markdown]
# #### 샘플 데이터 가져오기

# %%
고객 = load_data("customer_no_name")
고객
# Out:
# [data] https://data.hossam.kr/data/lab04/customer-no-name.xlsx
# [desc] 데이터프레임 병합 실습을 위한 고객번호와 고객 이름에 대한 가상 데이터(인덱스와 메타데이터 없음)
# [!] Cannot read metadata
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
매출 = load_data("customer_no_pay")
매출
# Out:
# [data] https://data.hossam.kr/data/lab04/customer-no-pay.xlsx
# [desc] 데이터프레임 병합 실습을 위한 고객번호와 매출액에 대한 가상 데이터(인덱스와 메타데이터 없음)
# [!] Cannot read metadata
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %% [markdown]
# #### 1. 일치하는 데이터 끼리 병합 (SQL의 innerjoin과 동일)

# %%
merge(고객,매출)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %% [markdown]
# #### 2. 왼쪽 데이터 프레임을 기준으로 병합 (SQL의 LEFTOUTERJOIN과 동일)

# %%
merge(고객,매출,how="left")
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %% [markdown]
# #### 2. 오른쪽 데이터 프레임을 기준으로 병합 (SQL의 RIGHT OUTERJOIN과 동일)

# %%
merge(고객,매출, how="right")
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1005   희동   15000
# 3  1006  마이콜    5000
# 4  1008  NaN  100000
# 5  1001   둘리   30000

# %%
cd1 = load_data("customer_data1")
cd1
# Out:
# [data] https://data.hossam.kr/data/lab04/customer_data1.xlsx
# [desc] 데이터 병합용 실습 데이터 (1) (인덱스/메타데이터 없음)
# [!] Cannot read metadata
#   고객명         날짜     데이터
# 0  민수 2018-01-01   20000
# 1  수영 2018-01-01  100000

# %%
cd2 = load_data("customer_data2")
cd2
# Out:
# [data] https://data.hossam.kr/data/lab04/customer_data2.xlsx
# [desc] 데이터 병합용 실습 데이터 (2) (인덱스/메타데이터 없음)
# [!] Cannot read metadata
#   고객명  데이터
# 0  민수  21세
# 1  수영  20세

# %% [markdown]
# # 오류 발생   cd1 은 int타입 cd2는 str 타입이라 병합기준 미충족
# #merge(cd1,cd2)

# %% [markdown]
# #### 3. 병합 기준 설정

# %%
tmp = merge(cd1,cd2,on='고객명')

# %%
tmp
# Out:
#   고객명         날짜   데이터_x 데이터_y
# 0  민수 2018-01-01   20000   21세
# 1  수영 2018-01-01  100000   20세

# %% [markdown]
# #### 4. 두 데이터 프레임의 모든 컬럼 이름이 다른 경우

# %%
df_left = DataFrame({'이름':['영희','철수'],'국어':[97,12]})
df_left
# Out:
#    이름  국어
# 0  영희  97
# 1  철수  12

# %%
df_right = DataFrame({'성명':['영희','철수'],'영어':[27,23]})
df_right
# Out:
#    성명  영어
# 0  영희  27
# 1  철수  23

# %%
r3 = merge(df_left,df_right,left_on=['이름'],right_on=['성명'])
r3
# Out:
#    이름  국어  성명  영어
# 0  영희  97  영희  27
# 1  철수  12  철수  23

# %% [markdown]
# #### 1. 학생의 이름을 인덱스로 갖는 두 데이터 프레임 생성

# %%
df_left = DataFrame({'수학':[90,12]},index=['민철','봉구'])
df_left
# Out:
#     수학
# 민철  90
# 봉구  12

# %%
df_right = DataFrame({'국어':[90,12]},index=['민철','철수'])
df_right
# Out:
#     국어
# 민철  90
# 철수  12

# %% [markdown]
# #### 2. 병합 조건에서 𝑖𝑛𝑑𝑒𝑥를 사용하도록 지정하여 𝐼𝑛𝑛𝑒𝑟 𝐽𝑜𝑖𝑛 하기

# %%
merge(df_left,df_right,left_index=True,right_index=True)
# Out:
#     수학  국어
# 민철  90  90

# %%
merge(df_left,df_right,left_index=True,right_index=True,how="left")
# Out:
#     수학    국어
# 민철  90  90.0
# 봉구  12   NaN

# %% [markdown]
# #### 4. 병합 조건에서 𝑖𝑛𝑑𝑒𝑥를 사용하도록 지정하여 𝑅𝑖𝑔ℎ𝑡 𝑂𝑢𝑡𝑒𝑟 𝐽𝑜𝑖𝑛 하기

# %%
merge(df_left,df_right,left_index=True,right_index=True,how="right")
# Out:
#       수학  국어
# 민철  90.0  90
# 철수   NaN  12

# %%
merge(df_left,df_right,left_index=True,right_index=True,how="outer")
# Out:
#       수학    국어
# 민철  90.0  90.0
# 봉구  12.0   NaN
# 철수   NaN  12.0

# %% [markdown]
# ### #05.인덱스와컬럼을각각기준으로하기

# %%
df_left = DataFrame({'수학':[90,12]},index=['민철','봉구'])
df_left
# Out:
#     수학
# 민철  90
# 봉구  12

# %%
df_right = DataFrame({'성명':['민철','철수'],'영어':[90,82]})
df_right
# Out:
#    성명  영어
# 0  민철  90
# 1  철수  82

# %%
merge(df_left,df_right,left_index=True,right_on=['성명'])
# Out:
#    수학  성명  영어
# 0  90  민철  90

# %%
merge(df_left,df_right,left_index=True,right_on=['성명'],how='left')
# Out:
#      수학  성명    영어
# 0.0  90  민철  90.0
# NaN  12  봉구   NaN

# %%
merge(df_left,df_right,left_index=True,right_on=['성명'],how='right')
# Out:
#      수학  성명  영어
# 0  90.0  민철  90
# 1   NaN  철수  82

# %%
tmp = merge(df_left,df_right,left_index=True,right_on=['성명'],how='outer')
tmp
# Out:
#        수학  성명    영어
# 0.0  90.0  민철  90.0
# NaN  12.0  봉구   NaN
# 1.0   NaN  철수  82.0

# %%
tmp2 = tmp.set_index('성명')
tmp2
# Out:
#       수학    영어
# 성명
# 민철  90.0  90.0
# 봉구  12.0   NaN
# 철수   NaN  82.0
